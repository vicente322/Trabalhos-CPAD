# %% [markdown]
# <h1>Buscando dados da internet</h1>

# %% [markdown]
# <h3>Laboratório de Coletas, Preparação e Análise de Dados.</h3>
# Desenvolvendo um crawler básico.
#
# Prof. Luan Garcia
#
# Baseado no material de Richard Mitchel
# https://github.com/REMitchell/python-scraping

# %% [markdown]
# Com a biblioteca Beautiful Soup vimos como é possível tratar documentos HTML como objetos no modelo DOM, buscando informação pelas *tags* e seus atributos. Porém, para chegarmos ao ponto de processar um documento HTML precisamos realizar o download do documento a partir do seu servidor web e como descobrir novos documentos a partir de um link de origem.
#
# Neste notebook, veremos como é possível fazer requisições HTTP utilizando a biblioteca urllib e como lidar com alguns problemas básicos que podem acontecer quando estamos trabalhando com um crawler.

# %% [markdown]
# Primeiro passo é importar o módulo request da biblioteca urllib. Não é necessário instalar, pois é uma biblioteca nativa do Python.

# %%
from urllib.request import urlopen

# %% [markdown]
# Para fazer o download do documento web, basta sabermos o endereço do documento e chamar o método read() do **urlopen**.

# %%
html = urlopen('http://127.0.0.1:8000/places/default/index')
print(html.read())

# %% [markdown]
# Para podermos tratar o documento utilizando a biblioteca BeautifulSoup podemos passar diretamente o documento carregado através da requisição HTTP e depois manipular conforme o necessário.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://127.0.0.1:8000/places/default/index')
bs = BeautifulSoup(html.read(), 'html.parser')
print(bs.h1)

# %% [markdown]
# Um problema bastante comum é o site que estamos tentando acessar não estar disponível, seja porque erramos o endereço, seja porque o servidor está fora do ar.
#
# Um solução simples é garantir que tenhamos um documento para tratar utilizando exceções.

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError

try:
    html = urlopen("http://127.0.0.1:8000/places/default/index")
except HTTPError as e:
    print("The server returned an HTTP error")
except URLError as e:
    print("The server could not be found!")
else:
    print(html.read())

# %% [markdown]
# O objetivo de um crawler é descobrir, a partir de um link raiz, outros documentos que estejam linkados de alguma forma.
#
# Uma maneira simples de realizar isto é filtrando pelas tags de links de um documento HTML. Com isto, encontramos todos os links dentro de um documento.
#
# Abaixo, um exemplo utilizando como raiz a página do ator Kevin Bacon na Wikipedia.

# %%
html = urlopen('http://127.0.0.1:8000/places/default/index')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a', id="places_neighbours__row"):
    if 'href' in link.attrs:
        print(link.attrs['href'])

# %%
import re
html = urlopen('http://127.0.0.1:8000/places/default/index')
bs = BeautifulSoup(html, 'html.parser')
bs.find_all("td")

# %% [markdown]
# Evidentemente, nem todos links serão de nosso interesse. Podemos filtrar apenas os links que nos interessam procurando por algum padrão no endereço e utilizar uma expressão regular para realizar o filtro.
#
# Abaixo, vamos filtrar apenas links para outros artigos da wiki, ignorando âncoras, links para arquivos, etc. Faremos isso nos aproveitando de conhecimento de como um verbete na wiki é organizado. Todos links de artigos estarão sempre dentro da tag **div** que contém um atributo de **id** com valor **'bodyContent'**. Além disso, todo link de verbete necessariamente começa com o endereço "/wiki/" e não possui ":" no endereço.

# %%
import re
from bs4 import BeautifulSoup

html = urlopen('http://127.0.0.1:8000/places/default/view/Afghanistan-1')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('tr', {'id':'places_neighbours__row'}).find_all(
     href=re.compile('/places/default/view/')):
    print(link.attrs['href'])

# %% [markdown]
# Podemos generalizar este código em forma de uma função **getLinks()**. Isto possibilitará que busquemos os links de qualquer verbete da wiki.

# %%
import re

def getLinks(articleUrl):
    html = urlopen('http://127.0.0.1:8000/places/default/index{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find_all(href=re.compile("/places/default/view/"))
for link in bs.find_all(href=re.compile("/places/default/index/")):
    links = getLinks('/default/index/')
    for i in range(len(links)):
        newArticle = links[i].attrs['href']
        print(newArticle)

# %%
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup

def getLinks(articleUrl):
    html = urlopen('http://127.0.0.1:8000/places/default/index{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    links = bs.find_all(href=re.compile("/places/default/index/"))
    for link in links:
        newArticle = link.attrs['href']
        print(newArticle)
        getLinks(newArticle)  # Recursive call

getLinks('/default/index')

# %% [markdown]
# A função **getLinks()** anterior funciona se quisermos encontrar todos os links de uma única página, porém, se quisermos fazer um crawler efetivo, precisamos procurar por páginas linkadas dentro de outras páginas de forma recursiva. Podemos fazer isso chamando a nosa própria função de procurar link de forma recursiva.

# %%
pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://127.0.0.1:8000/places/default/view/Afghanistan-1{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all(href=re.compile("/places/default/iso")):
        if link.attrs['href'] not in pages:
            newPage = link.attrs['href']
            print(newPage)
            pages.add(newPage)
            getLinks(newPage)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

link_list = []

def busca_links(site):
      soup = BeautifulSoup(site.read(), 'html.parser')
      table=soup.find_all('td')
      
      for tag in table:
            tag_link = tag.next_element.next_element
            link_list.append(tag_link.attrs['href'])

      for tag in soup.find_all('a'):
            if tag.string == "Next >":
                  if 'href' in tag.attrs:
                        html = urlopen('http://127.0.0.1:8000' + tag.attrs['href'])
                        busca_links(html)


html = urlopen('http://127.0.0.1:8000/places/default/index')

busca_links(html)

print(link_list)

# %% [markdown]
# Experimente executar o comando a seguir e veja o que acontece.

# %%
getLinks('')

# %% [markdown]
# O que aconteceu? Será que isto é um problema? Se for, como podemos solucioná-lo?

# %%
from urllib.request import urlopen

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.imdb.com/chart/toptv/?ref_=nv_tvv_250"

# Adicionando um cabeçalho de usuário
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Verifica se houve erro na solicitação
except requests.HTTPError as e:
    print("The server returned an HTTP error:", e)
except requests.RequestException as e:
    print("Request error:", e)
else:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
lista_series = soup.find('ul', class_='ipc-metadata-list ipc-metadata-list--dividers-between sc-a1e81754-0 eBRbsI compact-list-view ipc-metadata-list--base')
if lista_series:
    print("Elemento <ul> encontrado.")
    
    series = lista_series.find_all('li')
    num_series = len(series)
    print(f"Encontradas {num_series} séries dentro de <ul>.")
    
    if series:
        print("Elementos <li> encontrados dentro de <ul>.")
        for serie in series:
            print(serie.prettify())  # Exibe o conteúdo de cada <li>
    else:
        print("Nenhum elemento <li> encontrado dentro de <ul>.")
else:
    print("Elemento <ul> não encontrado.")
# Out:
# Elemento <ul> encontrado.
# Encontradas 250 séries dentro de <ul>.
# Elementos <li> encontrados dentro de <ul>.
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Bryan Cranston in Breaking Bad (2008)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BYmQ4YWMxYjUtNjZmYi00MDQ1LWFjMjMtNjA5ZDdiYjdiODU5XkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UX140_CR0,1,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BYmQ4YWMxYjUtNjZmYi00MDQ1LWFjMjMtNjA5ZDdiYjdiODU5XkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UX140_CR0,1,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BYmQ4YWMxYjUtNjZmYi00MDQ1LWFjMjMtNjA5ZDdiYjdiODU5XkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UX210_CR0,2,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BYmQ4YWMxYjUtNjZmYi00MDQ1LWFjMjMtNjA5ZDdiYjdiODU5XkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UX280_CR0,3,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Breaking Bad" class="ipc-lockup-overlay ipc-focusable" href="/title/tt0903747/?ref_=chttvtp_i_1">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt0903747/?ref_=chttvtp_t_1" tabindex="0">
#       <h3 class="ipc-title__text">
#        1. Breaking Bad
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2008–2013
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       62 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       16
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.5" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.5
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         2.1M
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Breaking Bad" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Breaking Bad" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Breaking Bad">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Planeta Terra II (2016)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BMGZmYmQ5NGQtNWQ1MC00NWZlLTg0MjYtYjJjMzQ5ODgxYzRkXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY207_CR3,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BMGZmYmQ5NGQtNWQ1MC00NWZlLTg0MjYtYjJjMzQ5ODgxYzRkXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY207_CR3,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BMGZmYmQ5NGQtNWQ1MC00NWZlLTg0MjYtYjJjMzQ5ODgxYzRkXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY311_CR4,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BMGZmYmQ5NGQtNWQ1MC00NWZlLTg0MjYtYjJjMzQ5ODgxYzRkXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY414_CR5,0,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Planeta Terra II" class="ipc-lockup-overlay ipc-focusable" href="/title/tt5491994/?ref_=chttvtp_i_2">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt5491994/?ref_=chttvtp_t_2" tabindex="0">
#       <h3 class="ipc-title__text">
#        2. Planeta Terra II
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2016
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       6 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       10
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.5" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.5
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         157K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Planeta Terra II" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Mini Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Planeta Terra II" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Planeta Terra II">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Planeta Terra (2006)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BMzMyYjg0MGMtMTlkMy00OGFiLWFiNTYtYmFmZWNmMDFlMzkwXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY207_CR3,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BMzMyYjg0MGMtMTlkMy00OGFiLWFiNTYtYmFmZWNmMDFlMzkwXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY207_CR3,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BMzMyYjg0MGMtMTlkMy00OGFiLWFiNTYtYmFmZWNmMDFlMzkwXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY311_CR4,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BMzMyYjg0MGMtMTlkMy00OGFiLWFiNTYtYmFmZWNmMDFlMzkwXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_QL75_UY414_CR5,0,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Planeta Terra" class="ipc-lockup-overlay ipc-focusable" href="/title/tt0795176/?ref_=chttvtp_i_3">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt0795176/?ref_=chttvtp_t_3" tabindex="0">
#       <h3 class="ipc-title__text">
#        3. Planeta Terra
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2006
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       11 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       Livre
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.4" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.4
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         219K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Planeta Terra" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Mini Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Planeta Terra" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Planeta Terra">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Donnie Wahlberg, Scott Grimes, Damian Lewis, Ron Livingston, Shane Taylor, and Peter Youngblood Hills in Irmãos de Guerra (2001)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BMTI3ODc2ODc0M15BMl5BanBnXkFtZTYwMjgzNjc3._V1_QL75_UX140_CR0,4,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BMTI3ODc2ODc0M15BMl5BanBnXkFtZTYwMjgzNjc3._V1_QL75_UX140_CR0,4,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BMTI3ODc2ODc0M15BMl5BanBnXkFtZTYwMjgzNjc3._V1_QL75_UX210_CR0,6,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BMTI3ODc2ODc0M15BMl5BanBnXkFtZTYwMjgzNjc3._V1_QL75_UX280_CR0,8,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Irmãos de Guerra" class="ipc-lockup-overlay ipc-focusable" href="/title/tt0185906/?ref_=chttvtp_i_4">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt0185906/?ref_=chttvtp_t_4" tabindex="0">
#       <h3 class="ipc-title__text">
#        4. Irmãos de Guerra
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2001
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       10 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       14
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.4" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.4
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         523K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Irmãos de Guerra" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Mini Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Irmãos de Guerra" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Irmãos de Guerra">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Chernobyl (2019)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BNTdkN2QwMDItMDVhNS00ZjFiLWEzNTctMzY5ODQzYWNkMDllXkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UY207_CR5,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BNTdkN2QwMDItMDVhNS00ZjFiLWEzNTctMzY5ODQzYWNkMDllXkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UY207_CR5,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BNTdkN2QwMDItMDVhNS00ZjFiLWEzNTctMzY5ODQzYWNkMDllXkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UY311_CR7,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BNTdkN2QwMDItMDVhNS00ZjFiLWEzNTctMzY5ODQzYWNkMDllXkEyXkFqcGdeQXVyMTMzNDExODE5._V1_QL75_UY414_CR10,0,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Chernobyl" class="ipc-lockup-overlay ipc-focusable" href="/title/tt7366338/?ref_=chttvtp_i_5">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt7366338/?ref_=chttvtp_t_5" tabindex="0">
#       <h3 class="ipc-title__text">
#        5. Chernobyl
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2019
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       5 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       16
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.3" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.3
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         858K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Chernobyl" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Mini Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Chernobyl" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Chernobyl">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Idris Elba, Wood Harris, Sonja Sohn, and Dominic West in A Escuta (2002)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BZmY5ZDMxODEtNWIwOS00NjdkLTkyMjktNWRjMDhmYjJjN2RmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_QL75_UX140_CR0,1,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BZmY5ZDMxODEtNWIwOS00NjdkLTkyMjktNWRjMDhmYjJjN2RmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_QL75_UX140_CR0,1,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BZmY5ZDMxODEtNWIwOS00NjdkLTkyMjktNWRjMDhmYjJjN2RmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_QL75_UX210_CR0,2,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BZmY5ZDMxODEtNWIwOS00NjdkLTkyMjktNWRjMDhmYjJjN2RmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_QL75_UX280_CR0,3,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for A Escuta" class="ipc-lockup-overlay ipc-focusable" href="/title/tt0306414/?ref_=chttvtp_i_6">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt0306414/?ref_=chttvtp_t_6" tabindex="0">
#       <h3 class="ipc-title__text">
#        6. A Escuta
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2002–2008
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       60 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       16
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.3" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.3
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         375K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate A Escuta" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about A Escuta" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about A Escuta">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Zach Tyler Eisen, Mae Whitman, and Jack De Sena in Avatar: A Lenda de Aang (2005)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BODc5YTBhMTItMjhkNi00ZTIxLWI0YjAtNTZmOTY0YjRlZGQ0XkEyXkFqcGdeQXVyODUwNjEzMzg@._V1_QL75_UY207_CR1,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BODc5YTBhMTItMjhkNi00ZTIxLWI0YjAtNTZmOTY0YjRlZGQ0XkEyXkFqcGdeQXVyODUwNjEzMzg@._V1_QL75_UY207_CR1,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BODc5YTBhMTItMjhkNi00ZTIxLWI0YjAtNTZmOTY0YjRlZGQ0XkEyXkFqcGdeQXVyODUwNjEzMzg@._V1_QL75_UY311_CR0,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BODc5YTBhMTItMjhkNi00ZTIxLWI0YjAtNTZmOTY0YjRlZGQ0XkEyXkFqcGdeQXVyODUwNjEzMzg@._V1_QL75_UY414_CR1,0,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Avatar: A Lenda de Aang" class="ipc-lockup-overlay ipc-focusable" href="/title/tt0417299/?ref_=chttvtp_i_7">
# ...
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Chef's Table" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Chef's Table">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Michael Kitchen in Foyle's War (2002)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BOWIyYjcwNGYtZTZkNS00ODE3LWFhMzEtODE3OGVkZWZjY2Q4XkEyXkFqcGdeQXVyMjExMjk0ODk@._V1_QL75_UY207_CR4,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BOWIyYjcwNGYtZTZkNS00ODE3LWFhMzEtODE3OGVkZWZjY2Q4XkEyXkFqcGdeQXVyMjExMjk0ODk@._V1_QL75_UY207_CR4,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BOWIyYjcwNGYtZTZkNS00ODE3LWFhMzEtODE3OGVkZWZjY2Q4XkEyXkFqcGdeQXVyMjExMjk0ODk@._V1_QL75_UY311_CR6,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BOWIyYjcwNGYtZTZkNS00ODE3LWFhMzEtODE3OGVkZWZjY2Q4XkEyXkFqcGdeQXVyMjExMjk0ODk@._V1_QL75_UY414_CR8,0,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Foyle's War" class="ipc-lockup-overlay ipc-focusable" href="/title/tt0310455/?ref_=chttvtp_i_249">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt0310455/?ref_=chttvtp_t_249" tabindex="0">
#       <h3 class="ipc-title__text">
#        249. Foyle's War
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2002–2015
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       28 eps
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       TV-14
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 8.6" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        8.6
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         18K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Foyle's War" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Foyle's War" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Foyle's War">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>
#
# <li class="ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent">
#  <div class="sc-e5a25b0f-0 jQjDIb cli-poster-container">
#   <div class="ipc-poster ipc-poster--base ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group">
#    <div aria-label="add to watchlist" class="ipc-watchlist-ribbon ipc-focusable ipc-watchlist-ribbon--s ipc-watchlist-ribbon--base ipc-watchlist-ribbon--loading ipc-watchlist-ribbon--onImage ipc-poster__watchlist-ribbon" role="button" tabindex="0">
#     <svg class="ipc-watchlist-ribbon__bg" height="34px" role="presentation" viewbox="0 0 24 34" width="24px" xmlns="http://www.w3.org/2000/svg">
#      <polygon class="ipc-watchlist-ribbon__bg-ribbon" fill="#000000" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-hover" points="24 0 0 0 0 32 12.2436611 26.2926049 24 31.7728343">
#      </polygon>
#      <polygon class="ipc-watchlist-ribbon__bg-shadow" points="24 31.7728343 24 33.7728343 12.2436611 28.2926049 0 34 0 32 12.2436611 26.2926049">
#      </polygon>
#     </svg>
#     <div class="ipc-watchlist-ribbon__icon" role="presentation">
#      <svg class="ipc-loader ipc-loader--circle ipc-watchlist-ribbon__loader" data-testid="watchlist-ribbon-loader" height="48px" role="presentation" version="1.1" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg">
#       <g class="ipc-loader__container" fill="currentColor">
#        <circle class="ipc-loader__circle ipc-loader__circle--one" cx="24" cy="9" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--two" cx="35" cy="14" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--three" cx="39" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--four" cx="35" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--five" cx="24" cy="39" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--six" cx="13" cy="34" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--seven" cx="9" cy="24" r="4">
#        </circle>
#        <circle class="ipc-loader__circle ipc-loader__circle--eight" cx="13" cy="14" r="4">
#        </circle>
#       </g>
#      </svg>
#     </div>
#    </div>
#    <div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--base ipc-media--poster-m ipc-poster__poster-image ipc-media__img" style="width:100%">
#     <img alt="Vaisakh Shankar, Sukhwinder Chahal, Vijayant Kohli, and Ambrish Verma in Sapne Vs Everyone (2023)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BNmZmNTA5ZTgtNTgzOS00YWQ5LTgxZTItYTc1NzNjOWNmMDA5XkEyXkFqcGdeQXVyMTExMTIzMTA5._V1_QL75_UX140_CR0,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BNmZmNTA5ZTgtNTgzOS00YWQ5LTgxZTItYTc1NzNjOWNmMDA5XkEyXkFqcGdeQXVyMTExMTIzMTA5._V1_QL75_UX140_CR0,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BNmZmNTA5ZTgtNTgzOS00YWQ5LTgxZTItYTc1NzNjOWNmMDA5XkEyXkFqcGdeQXVyMTExMTIzMTA5._V1_QL75_UX210_CR0,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BNmZmNTA5ZTgtNTgzOS00YWQ5LTgxZTItYTc1NzNjOWNmMDA5XkEyXkFqcGdeQXVyMTExMTIzMTA5._V1_QL75_UX280_CR0,0,280,414_.jpg 280w" width="140"/>
#    </div>
#    <a aria-label="View title page for Sapne Vs Everyone" class="ipc-lockup-overlay ipc-focusable" href="/title/tt30263074/?ref_=chttvtp_i_250">
#     <div class="ipc-lockup-overlay__screen">
#     </div>
#    </a>
#   </div>
#  </div>
#  <div class="ipc-metadata-list-summary-item__c">
#   <div class="ipc-metadata-list-summary-item__tc">
#    <span aria-disabled="false" class="ipc-metadata-list-summary-item__t">
#    </span>
#    <div class="sc-b0691f29-0 jbYPfh cli-children">
#     <div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b0691f29-9 klOwFB cli-title">
#      <a class="ipc-title-link-wrapper" href="/title/tt30263074/?ref_=chttvtp_t_250" tabindex="0">
#       <h3 class="ipc-title__text">
#        250. Sapne Vs Everyone
#       </h3>
#      </a>
#     </div>
#     <div class="sc-b0691f29-7 hrgukm cli-title-metadata">
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       2023–
#      </span>
#      <span class="sc-b0691f29-8 ilsLEX cli-title-metadata-item">
#       5 eps
#      </span>
#     </div>
#     <span class="sc-b0691f29-1 grHDBY">
#      <div class="sc-e2dbc1a3-0 ajrIH sc-b0691f29-2 bhhtyj cli-ratings-container" data-testid="ratingGroup--container">
#       <span aria-label="IMDb rating: 9.4" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating">
#        <svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M12 20.1l5.82 3.682c1.066.675 2.37-.322 2.09-1.584l-1.543-6.926 5.146-4.667c.94-.85.435-2.465-.799-2.567l-6.773-.602L13.29.89a1.38 1.38 0 0 0-2.581 0l-2.65 6.53-6.774.602C.052 8.126-.453 9.74.486 10.59l5.147 4.666-1.542 6.926c-.28 1.262 1.023 2.26 2.09 1.585L12 20.099z">
#         </path>
#        </svg>
#        9.4
#        <span class="ipc-rating-star--voteCount">
#         (
#         <!-- -->
#         62K
#         <!-- -->
#         )
#        </span>
#       </span>
#       <button aria-label="Rate Sapne Vs Everyone" class="ipc-rate-button sc-e2dbc1a3-1 jboOQc ratingGroup--user-rating ipc-rate-button--unrated ipc-rate-button--base" data-testid="rate-button">
#        <span class="ipc-rating-star ipc-rating-star--base ipc-rating-star--rate">
#         <svg class="ipc-icon ipc-icon--star-border-inline" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.724 8.217l-6.786-.587-2.65-6.22c-.477-1.133-2.103-1.133-2.58 0l-2.65 6.234-6.772.573c-1.234.098-1.739 1.636-.8 2.446l5.146 4.446-1.542 6.598c-.28 1.202 1.023 2.153 2.09 1.51l5.818-3.495 5.819 3.509c1.065.643 2.37-.308 2.089-1.51l-1.542-6.612 5.145-4.446c.94-.81.45-2.348-.785-2.446zm-10.726 8.89l-5.272 3.174 1.402-5.983-4.655-4.026 6.141-.531 2.384-5.634 2.398 5.648 6.14.531-4.654 4.026 1.402 5.983-5.286-3.187z">
#          </path>
#         </svg>
#         <span class="ipc-rating-star--rate">
#          Rate
#         </span>
#        </span>
#       </button>
#      </div>
#      <span class="sc-b0691f29-3 iobobZ cli-title-type-data">
#       TV Series
#      </span>
#     </span>
#    </div>
#   </div>
#  </div>
#  <div class="sc-10233bc-1 lkPiVh cli-post-element">
#   <button aria-disabled="false" aria-label="See more information about Sapne Vs Everyone" class="ipc-icon-button cli-info-icon ipc-icon-button--base ipc-icon-button--onAccent2" role="button" tabindex="0" title="See more information about Sapne Vs Everyone">
#    <svg class="ipc-icon ipc-icon--info" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 0h24v24H0V0z" fill="none">
#     </path>
#     <path d="M11 7h2v2h-2zm0 4h2v6h-2zm1-9C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z">
#     </path>
#    </svg>
#   </button>
#  </div>
# </li>

# %%
import requests
from bs4 import BeautifulSoup

def pega_autores():
    # Adicionando um cabeçalho de usuário
    url = "https://www.imdb.com/title/tt0903747/?ref_=chttvtp_t_1"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    try:
        response_serie = requests.get(url, headers=headers)  # Corrigindo a passagem da URL
        response_serie.raise_for_status()
    except requests.HTTPError as e:
        print("The server returned an HTTP error:", e)
        return None
    except requests.RequestException as e:
        print("Request error:", e)
        return None
    else:
        html_serie = response_serie.text
        soup = BeautifulSoup(html_serie, 'html.parser')
        lista_div = soup.find('div', class_="ipc-chip-list__scroller")
        lista_span = lista_div.find_all('span', class_="ipc-chip__text")
        for span in lista_span:
            print(span.text)
        

# Exemplo de uso:
pega_autores()
# Out:
# Crime
# Drama
# Thriller

# %%
import requests
from bs4 import BeautifulSoup
import re   

url = "https://www.imdb.com/chart/toptv/?ref_=nv_tvv_250"

# Adicionando um cabeçalho de usuário
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()
except requests.HTTPError as e:
    print("The server returned an HTTP error:", e)
except requests.RequestException as e:
    print("Request error:", e)
else:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    lista_series = soup.find('ul', class_="ipc-metadata-list ipc-metadata-list--dividers-between sc-a1e81754-0 eBRbsI compact-list-view ipc-metadata-list--base")
    if lista_series:
        series = lista_series.find_all('li')
        
    for serie in series:
        titulo_elemento = serie.find(class_= "ipc-title__text").text
        print(titulo_elemento)
        ano_estreia_elemento = serie.find(class_="sc-b0691f29-8 ilsLEX cli-title-metadata-item").text
        div = soup.find('div', class_="sc-b0691f29-7 hrgukm cli-title-metadata")
        spans = div.find_all('span', class_="sc-b0691f29-8 ilsLEX cli-title-metadata-item")
        
        if len(spans)>= 2:
            numero_episodios = spans[1].text
            print(numero_episodios)
            
        rating = serie.find(class_= "ipc-rating-star").text
        link_pagina_filme = serie.find("a", class_= "ipc-title-link-wrapper")
        re2_result = re.search(r'\d{4}',ano_estreia_elemento)
        
        if re2_result:
            ano_estreia_elemento = re.search(r'\d{4}',ano_estreia_elemento).group(0)
            print(ano_estreia_elemento)
            
        re_result = re.search(r'^\d\.\d',rating) #aplicando a regex para extrair apenas o padrão 'digito ponto digito'
        
        if re_result:
            rating = re.search(r'^\d\.\d',rating).group(0) #string resultante da regex
            print(rating)
            
        link = link_pagina_filme["href"]
        print(link)
# Out:
# 1. Breaking Bad
# 62 eps
# 2008
# 9.5
# /title/tt0903747/?ref_=chttvtp_t_1
# 2. Planeta Terra II
# 62 eps
# 2016
# 9.5
# /title/tt5491994/?ref_=chttvtp_t_2
# 3. Planeta Terra
# 62 eps
# 2006
# 9.4
# /title/tt0795176/?ref_=chttvtp_t_3
# 4. Irmãos de Guerra
# 62 eps
# 2001
# 9.4
# /title/tt0185906/?ref_=chttvtp_t_4
# 5. Chernobyl
# 62 eps
# 2019
# 9.3
# /title/tt7366338/?ref_=chttvtp_t_5
# 6. A Escuta
# 62 eps
# 2002
# 9.3
# /title/tt0306414/?ref_=chttvtp_t_6
# 7. Avatar: A Lenda de Aang
# 62 eps
# 2005
# 9.3
# /title/tt0417299/?ref_=chttvtp_t_7
# 8. Planeta Azul II
# 62 eps
# 2017
# 9.3
# /title/tt6769208/?ref_=chttvtp_t_8
# 9. Família Soprano
# 62 eps
# 1999
# 9.2
# /title/tt0141842/?ref_=chttvtp_t_9
# 10. Cosmos: Uma Odisseia do Espaço-Tempo
# 62 eps
# 2014
# 9.3
# /title/tt2395695/?ref_=chttvtp_t_10
# 11. Cosmos
# 62 eps
# 1980
# 9.3
# /title/tt0081846/?ref_=chttvtp_t_11
# 12. Nosso Planeta
# 62 eps
# 2019
# 9.3
# /title/tt9253866/?ref_=chttvtp_t_12
# 13. Game of Thrones
# 62 eps
# 2011
# 9.2
# /title/tt0944947/?ref_=chttvtp_t_13
# 14. O Mundo em Guerra
# 62 eps
# 1973
# 9.2
# /title/tt0071075/?ref_=chttvtp_t_14
# 15. Bluey
# 62 eps
# 2018
# 9.4
# /title/tt7678620/?ref_=chttvtp_t_15
# 16. Rick e Morty
# 62 eps
# 2013
# 9.1
# /title/tt2861424/?ref_=chttvtp_t_16
# 17. Fullmetal Alchemist: Brotherhood
# 62 eps
# 2009
# 9.1
# /title/tt1355642/?ref_=chttvtp_t_17
# 18. Vida
# 62 eps
# 2009
# 9.1
# /title/tt1533395/?ref_=chttvtp_t_18
# 19. Arremesso Final
# 62 eps
# 2020
# 9.1
# /title/tt8420184/?ref_=chttvtp_t_19
# 20. Além da Imaginação
# 62 eps
# 1959
# 9.1
# /title/tt0052520/?ref_=chttvtp_t_20
# 21. Sherlock
# 62 eps
# 2010
# 9.1
# /title/tt1475582/?ref_=chttvtp_t_21
# 22. A Guerra do Vietnã
# 62 eps
# 2017
# 9.1
# /title/tt1877514/?ref_=chttvtp_t_22
# 23. Batman: A Série Animada
# 62 eps
# 1992
# 9.0
# /title/tt0103359/?ref_=chttvtp_t_23
# 24. Xógun: A Gloriosa Saga do Japão
# 62 eps
# 2024
# 9.1
# /title/tt2788316/?ref_=chttvtp_t_24
# 25. Ataque dos Titãs
# 62 eps
# 2013
# 9.1
# /title/tt2560140/?ref_=chttvtp_t_25
# 26. Scam 1992: The Harshad Mehta Story
# 62 eps
# 2020
# 9.3
# /title/tt12392504/?ref_=chttvtp_t_26
# 27. Vida de Escritório
# 62 eps
# 2005
# 9.0
# /title/tt0386676/?ref_=chttvtp_t_27
# 28. Arcane
# 62 eps
# 2021
# 9.0
# /title/tt11126994/?ref_=chttvtp_t_28
# 29. Planeta Azul
# 62 eps
# 2001
# 9.0
# /title/tt0296310/?ref_=chttvtp_t_29
# 30. Better Call Saul
# 62 eps
# 2015
# 9.0
# /title/tt3032476/?ref_=chttvtp_t_30
# 31. Planeta Humano
# 62 eps
# 2011
# 9.0
# /title/tt1806234/?ref_=chttvtp_t_31
# 32. Firefly
# 62 eps
# 2002
# 9.0
# /title/tt0303461/?ref_=chttvtp_t_32
# 33. Planeta Gelado
# 62 eps
# 2011
# 9.0
# /title/tt2092588/?ref_=chttvtp_t_33
# 34. Na Fazenda com Clarkson
# 62 eps
# 2021
# 9.0
# /title/tt10541088/?ref_=chttvtp_t_34
# 35. HUNTER×HUNTER
# 62 eps
# 2011
# 9.0
# /title/tt2098220/?ref_=chttvtp_t_35
# 36. Only Fools and Horses
# 62 eps
# 1981
# 9.0
# /title/tt0081912/?ref_=chttvtp_t_36
# 37. Death Note
# 62 eps
# 2006
# 8.9
# /title/tt0877057/?ref_=chttvtp_t_37
# 38. The Civil War
# 62 eps
# 1990
# 9.0
# /title/tt0098769/?ref_=chttvtp_t_38
# 39. Seinfeld
# 62 eps
# 1989
# 8.9
# /title/tt0098904/?ref_=chttvtp_t_39
# 40. Decálogo
# 62 eps
# 1989
# 8.9
# /title/tt0092337/?ref_=chttvtp_t_40
# 41. The Beatles: Get Back
# 62 eps
# 2021
# 9.0
# /title/tt9735318/?ref_=chttvtp_t_41
# 42. True Detective
# 62 eps
# 2014
# 8.9
# /title/tt2356777/?ref_=chttvtp_t_42
# 43. Sahsiyet
# 62 eps
# 2018
# 9.0
# /title/tt7920978/?ref_=chttvtp_t_43
# 44. Gravity Falls: Um Verão de Mistérios
# 62 eps
# 2012
# 8.9
# /title/tt1865718/?ref_=chttvtp_t_44
# 45. Cowboy Bebop
# 62 eps
# 1998
# 8.9
# /title/tt0213338/?ref_=chttvtp_t_45
# 46. Fargo
# 62 eps
# 2014
# 8.9
# /title/tt2802850/?ref_=chttvtp_t_46
# 47. Nathan for You
# 62 eps
# 2013
# 8.9
# /title/tt2297757/?ref_=chttvtp_t_47
# 48. Redescobrindo a Segunda Guerra
# 62 eps
# 2009
# 9.0
# /title/tt1508238/?ref_=chttvtp_t_48
# 49. Olhos que Condenam
# 62 eps
# 2019
# 8.8
# /title/tt7137906/?ref_=chttvtp_t_49
# 50. Last Week Tonight with John Oliver
# 62 eps
# 2014
# 8.9
# /title/tt3530232/?ref_=chttvtp_t_50
# 51. Taskmaster
# 62 eps
# 2015
# 9.0
# /title/tt4934214/?ref_=chttvtp_t_51
# 52. África
# 62 eps
# 2013
# 8.9
# /title/tt2571774/?ref_=chttvtp_t_52
# 53. Friends
# 62 eps
# 1994
# 8.9
# /title/tt0108778/?ref_=chttvtp_t_53
# 54. Succession
# 62 eps
# 2018
# 8.8
# /title/tt7660850/?ref_=chttvtp_t_54
# 55. Gibi
# 62 eps
# 2021
# 9.0
# /title/tt13675832/?ref_=chttvtp_t_55
# 56. TVF Pitchers
# 62 eps
# 2015
# 9.1
# /title/tt4742876/?ref_=chttvtp_t_56
# 57. It's Always Sunny in Philadelphia
# 62 eps
# 2005
# 8.8
# /title/tt0472954/?ref_=chttvtp_t_57
# 58. Monty Python's Flying Circus
# 62 eps
# 1969
# 8.8
# /title/tt0063929/?ref_=chttvtp_t_58
# 59. West Wing: Nos Bastidores do Poder
# 62 eps
# 1999
# 8.9
# /title/tt0200276/?ref_=chttvtp_t_59
# 60. SU-Boots: Submersos Em Guerras
# 62 eps
# 1985
# 8.8
# /title/tt0081834/?ref_=chttvtp_t_60
# 61. Segura a Onda
# 62 eps
# 2000
# 8.8
# /title/tt0264235/?ref_=chttvtp_t_61
# 62. One Piece
# 62 eps
# 1999
# 9.0
# /title/tt0388629/?ref_=chttvtp_t_62
# 63. BoJack Horseman
# 62 eps
# 2014
# 8.8
# /title/tt3398228/?ref_=chttvtp_t_63
# 64. Fawlty Towers
# 62 eps
# 1975
# 8.8
# /title/tt0072500/?ref_=chttvtp_t_64
# 65. Leyla ile Mecnun
# 62 eps
# 2011
# 9.1
# /title/tt1831164/?ref_=chttvtp_t_65
# 66. Orgulho e Preconceito
# 62 eps
# 1995
# 8.8
# /title/tt0112130/?ref_=chttvtp_t_66
# 67. Freaks & Geeks
# 62 eps
# 1999
# 8.8
# /title/tt0193676/?ref_=chttvtp_t_67
# 68. Blackadder Goes Forth
# 62 eps
# 1989
# 8.8
# /title/tt0096548/?ref_=chttvtp_t_68
# 69. Twin Peaks
# 62 eps
# 1990
# 8.8
# /title/tt0098936/?ref_=chttvtp_t_69
# 70. Dragon Ball Z
# 62 eps
# 1989
# 8.8
# /title/tt0214341/?ref_=chttvtp_t_70
# 71. Narcos
# 62 eps
# 2015
# 8.8
# /title/tt2707408/?ref_=chttvtp_t_71
# 72. Chappelle's Show
# 62 eps
# 2003
# 8.8
# /title/tt0353049/?ref_=chttvtp_t_72
# 73. Dragon Ball Z
# 62 eps
# 1989
# 8.8
# /title/tt0121220/?ref_=chttvtp_t_73
# 74. Responde 1988
# 62 eps
# 2015
# 9.1
# /title/tt5182866/?ref_=chttvtp_t_74
# 75. Eu, Cláudio
# 62 eps
# 1976
# 8.8
# /title/tt0074006/?ref_=chttvtp_t_75
# 76. Black Mirror
# 62 eps
# 2011
# 8.7
# /title/tt2085059/?ref_=chttvtp_t_76
# 77. South Park
# 62 eps
# 1997
# 8.7
# /title/tt0121955/?ref_=chttvtp_t_77
# 78. Ted Lasso
# 62 eps
# 2020
# 8.8
# /title/tt10986410/?ref_=chttvtp_t_78
# 79. O Segredo Além do Jardim
# 62 eps
# 2014
# 8.8
# /title/tt3718778/?ref_=chttvtp_t_79
# 80. Vinland Saga
# 62 eps
# 2019
# 8.8
# /title/tt10233448/?ref_=chttvtp_t_80
# 81. A Fábrica de Kota
# 62 eps
# 2019
# 9.0
# /title/tt9432978/?ref_=chttvtp_t_81
# 82. Gullak
# 62 eps
# 2019
# 9.1
# /title/tt10530900/?ref_=chttvtp_t_82
# 83. The Last of Us
# 62 eps
# 2023
# 8.7
# /title/tt3581920/?ref_=chttvtp_t_83
# 84. Peaky Blinders: Sangue, Apostas e Navalhas
# 62 eps
# 2013
# 8.8
# /title/tt2442560/?ref_=chttvtp_t_84
# 85. A Sete Palmos
# 62 eps
# 2001
# 8.7
# /title/tt0248654/?ref_=chttvtp_t_85
# 86. Roma
# 62 eps
# 2005
# 8.7
# /title/tt0384766/?ref_=chttvtp_t_86
# 87. Panchayat
# 62 eps
# 2020
# 8.9
# /title/tt12004706/?ref_=chttvtp_t_87
# 88. Oz
# 62 eps
# 1997
# 8.7
# /title/tt0118421/?ref_=chttvtp_t_88
# 89. Steins;Gate
# 62 eps
# 2011
# 8.8
# /title/tt1910272/?ref_=chttvtp_t_89
# 90. Dark
# 62 eps
# 2017
# 8.7
# /title/tt5753856/?ref_=chttvtp_t_90
# 91. Samurai de Olhos Azuis
# 62 eps
# 2023
# 8.7
# /title/tt13309742/?ref_=chttvtp_t_91
# 92. Bleach: Thousand-Year Blood War
# 62 eps
# 2022
# 9.0
# /title/tt14986406/?ref_=chttvtp_t_92
# 93. The Boys
# 62 eps
# 2019
# 8.7
# /title/tt1190634/?ref_=chttvtp_t_93
# 94. Fleabag
# 62 eps
# 2016
# 8.7
# /title/tt5687612/?ref_=chttvtp_t_94
# 95. Frieren e a Jornada para o Além
# 62 eps
# 2023
# 9.0
# /title/tt22248376/?ref_=chttvtp_t_95
# 96. Battlestar Galactica
# 62 eps
# 2004
# 8.7
# /title/tt0407362/?ref_=chttvtp_t_96
# 97. The Shield: Acima da Lei
# 62 eps
# 2002
# 8.7
# /title/tt0286486/?ref_=chttvtp_t_97
# 98. Downton Abbey
# 62 eps
# 2010
# 8.7
# /title/tt1606375/?ref_=chttvtp_t_98
# 99. Os Simpsons
# 62 eps
# 1989
# 8.7
# /title/tt0096697/?ref_=chttvtp_t_99
# 100. Berserk
# 62 eps
# 1997
# 8.7
# /title/tt0318871/?ref_=chttvtp_t_100
# 101. Caindo na Real
# 62 eps
# 2003
# 8.7
# /title/tt0367279/?ref_=chttvtp_t_101
# 102. Ruptura
# 62 eps
# 2022
# 8.7
# /title/tt11280740/?ref_=chttvtp_t_102
# 103. Dr. House
# 62 eps
# 2004
# 8.7
# /title/tt0412142/?ref_=chttvtp_t_103
# 104. One Punch Man
# 62 eps
# 2015
# 8.7
# /title/tt4508902/?ref_=chttvtp_t_104
# 105. Mad Men: Inventando Verdades
# 62 eps
# 2007
# 8.7
# /title/tt0804503/?ref_=chttvtp_t_105
# 106. Invencível
# 62 eps
# 2021
# 8.7
# /title/tt6741278/?ref_=chttvtp_t_106
# 107. Peep Show
# 62 eps
# 2003
# 8.7
# /title/tt0387764/?ref_=chttvtp_t_107
# 108. Jornada nas Estrelas: A Nova Geração
# 62 eps
# 1987
# 8.7
# /title/tt0092455/?ref_=chttvtp_t_108
# 109. Stranger Things
# 62 eps
# 2016
# 8.7
# /title/tt4574334/?ref_=chttvtp_t_109
# 110. Mahabharat
# 62 eps
# 1988
# 8.9
# /title/tt0158417/?ref_=chttvtp_t_110
# 111. The Adventures of Sherlock Holmes
# 62 eps
# 1984
# 8.7
# /title/tt0086661/?ref_=chttvtp_t_111
# 112. Maravilhosa Sra. Maisel
# 62 eps
# 2017
# 8.7
# /title/tt5788792/?ref_=chttvtp_t_112
# 113. The Grand Tour
# 62 eps
# 2016
# 8.7
# /title/tt5712554/?ref_=chttvtp_t_113
# 114. Liga da Justiça sem Limites
# 62 eps
# 2004
# 8.7
# /title/tt6025022/?ref_=chttvtp_t_114
# 115. Aspirants
# 62 eps
# 2021
# 9.2
# /title/tt14392248/?ref_=chttvtp_t_115
# 116. Friday Night Lights
# 62 eps
# 2006
# 8.7
# /title/tt0758745/?ref_=chttvtp_t_116
# 117. O Mandaloriano
# 62 eps
# 2019
# 8.7
# /title/tt8111088/?ref_=chttvtp_t_117
# 118. Sarabhai V/S Sarabhai
# 62 eps
# 2004
# 8.9
# /title/tt1518542/?ref_=chttvtp_t_118
# 119. Behzat Ç.: Bir Ankara Polisiyesi
# 62 eps
# 2010
# 8.9
# /title/tt1795096/?ref_=chttvtp_t_119
# 120. Line of Duty
# 62 eps
# 2012
# 8.7
# /title/tt2303687/?ref_=chttvtp_t_120
# 121. Top Gear
# 62 eps
# 2002
# 8.7
# /title/tt1628033/?ref_=chttvtp_t_121
# 122. Naruto Shippuden
# 62 eps
# 2007
# 8.7
# /title/tt0988824/?ref_=chttvtp_t_122
# 123. 1883
# 62 eps
# 2021
# 8.7
# /title/tt13991232/?ref_=chttvtp_t_123
# 124. The Thick of It
# 62 eps
# 2005
# 8.7
# /title/tt0459159/?ref_=chttvtp_t_124
# 125. Monster
# 62 eps
# 2004
# 8.7
# /title/tt0434706/?ref_=chttvtp_t_125
# 126. How to with John Wilson
# 62 eps
# 2020
# 8.7
# /title/tt10801534/?ref_=chttvtp_t_126
# 127. House of Cards
# 62 eps
# 2013
# 8.6
# /title/tt1856010/?ref_=chttvtp_t_127
# 128. This Is Us: Histórias de Família
# 62 eps
# 2016
# 8.7
# /title/tt5555260/?ref_=chttvtp_t_128
# 129. Father Ted
# 62 eps
# 1995
# 8.7
# /title/tt0111958/?ref_=chttvtp_t_129
# 130. Ramayan
# 62 eps
# 1987
# 9.0
# /title/tt0268093/?ref_=chttvtp_t_130
# 131. Atlanta
# 62 eps
# 2016
# 8.6
# /title/tt4288182/?ref_=chttvtp_t_131
# 132. Parks & Recreation: Confusões de Leslie
# 62 eps
# 2009
# 8.6
# /title/tt1266020/?ref_=chttvtp_t_132
# 133. The Crown
# 62 eps
# 2016
# 8.6
# /title/tt4786824/?ref_=chttvtp_t_133
# 134. Deadwood: Cidade Sem Lei
# 62 eps
# 2004
# 8.6
# /title/tt0348914/?ref_=chttvtp_t_134
# 135. Arquivo X
# 62 eps
# 1993
# 8.6
# /title/tt0106179/?ref_=chttvtp_t_135
# 136. Dexter
# 62 eps
# 2006
# 8.6
# /title/tt0773262/?ref_=chttvtp_t_136
# 137. Code Geass: Lelouch of the Rebellion
# 62 eps
# 2006
# 8.7
# /title/tt0994314/?ref_=chttvtp_t_137
# 138. Critical Role
# 62 eps
# 2015
# 9.2
# /title/tt4834232/?ref_=chttvtp_t_138
# 139. Primal
# 62 eps
# 2019
# 8.7
# /title/tt10332508/?ref_=chttvtp_t_139
# 140. It's a Sin
# 62 eps
# 2021
# 8.7
# /title/tt9140342/?ref_=chttvtp_t_140
# 141. Hora de Aventura
# 62 eps
# 2010
# 8.6
# /title/tt1305826/?ref_=chttvtp_t_141
# 142. The Jinx: A Vida e as Mortes de Robert Durst
# 62 eps
# 2015
# 8.6
# /title/tt4299972/?ref_=chttvtp_t_142
# 143. The Bridge
# 62 eps
# 2011
# 8.6
# /title/tt1733785/?ref_=chttvtp_t_143
# 144. Demolidor
# 62 eps
# 2015
# 8.6
# /title/tt3322312/?ref_=chttvtp_t_144
# 145. Blackadder II
# 62 eps
# 1986
# 8.6
# /title/tt0088484/?ref_=chttvtp_t_145
# 146. Os Pistoleiros do Oeste
# 62 eps
# 1989
# 8.7
# /title/tt0096639/?ref_=chttvtp_t_146
# 147. Yeh Meri Family
# 62 eps
# 2018
# 9.0
# /title/tt8595766/?ref_=chttvtp_t_147
# 148. Mindhunter
# 62 eps
# 2017
# 8.6
# /title/tt5290382/?ref_=chttvtp_t_148
# 149. Haikyuu!!
# 62 eps
# 2014
# 8.7
# /title/tt3398540/?ref_=chttvtp_t_149
# 150. The Return of Sherlock Holmes
# 62 eps
# 1986
# 8.7
# /title/tt0090509/?ref_=chttvtp_t_150
# 151. The Offer
# 62 eps
# 2022
# 8.6
# /title/tt13111040/?ref_=chttvtp_t_151
# 152. Poirot
# 62 eps
# 1989
# 8.6
# /title/tt0094525/?ref_=chttvtp_t_152
# 153. Gomorra: La serie
# 62 eps
# 2014
# 8.6
# /title/tt2049116/?ref_=chttvtp_t_153
# 154. Mr. Bean
# 62 eps
# 1990
# 8.6
# /title/tt0096657/?ref_=chttvtp_t_154
# 155. Mystery Science Theater 3000
# 62 eps
# 1988
# 8.6
# /title/tt0094517/?ref_=chttvtp_t_155
# 156. Blackadder the Third
# 62 eps
# 1987
# 8.6
# /title/tt0092324/?ref_=chttvtp_t_156
# 157. Pousando no Amor
# 62 eps
# 2019
# 8.7
# /title/tt10850932/?ref_=chttvtp_t_157
# 158. Pose
# 62 eps
# 2018
# 8.6
# /title/tt7562112/?ref_=chttvtp_t_158
# 159. Archer
# 62 eps
# 2009
# 8.6
# /title/tt1486217/?ref_=chttvtp_t_159
# 160. Demon Slayer: Kimetsu no Yaiba
# 62 eps
# 2019
# 8.6
# /title/tt9335498/?ref_=chttvtp_t_160
# 161. Anne com um E
# 62 eps
# 2017
# 8.6
# /title/tt5421602/?ref_=chttvtp_t_161
# 162. Planeta dos Abutres
# 62 eps
# 2023
# 8.7
# /title/tt21056886/?ref_=chttvtp_t_162
# 163. Justiça Jovem
# 62 eps
# 2010
# 8.6
# /title/tt1641384/?ref_=chttvtp_t_163
# 164. Dopesick
# 62 eps
# 2021
# 8.6
# /title/tt9174558/?ref_=chttvtp_t_164
# 165. Yes Minister
# 62 eps
# 1980
# 8.7
# /title/tt0080306/?ref_=chttvtp_t_165
# 166. Grandes Momentos da Segunda Guerra em Cores
# 62 eps
# 2019
# 8.7
# /title/tt9103932/?ref_=chttvtp_t_166
# 167. Mr Inbetween
# 62 eps
# 2018
# 8.6
# /title/tt7472896/?ref_=chttvtp_t_167
# 168. O Urso
# 62 eps
# 2022
# 8.6
# /title/tt14452776/?ref_=chttvtp_t_168
# 169. The Newsroom
# 62 eps
# 2012
# 8.6
# /title/tt1870479/?ref_=chttvtp_t_169
# 170. Yellowstone
# 62 eps
# 2018
# 8.7
# /title/tt4236770/?ref_=chttvtp_t_170
# 171. QI
# 62 eps
# 2003
# 8.6
# /title/tt0380136/?ref_=chttvtp_t_171
# 172. Boardwalk Empire: O Império do Contrabando
# 62 eps
# 2010
# 8.6
# /title/tt0979432/?ref_=chttvtp_t_172
# 173. Justified
# 62 eps
# 2010
# 8.6
# /title/tt1489428/?ref_=chttvtp_t_173
# 174. O Show do Pernalonga
# 62 eps
# 1960
# 8.6
# /title/tt0053488/?ref_=chttvtp_t_174
# 175. Chaves
# 62 eps
# 1972
# 8.7
# /title/tt0229889/?ref_=chttvtp_t_175
# 176. Le Bureau des Légendes
# 62 eps
# 2015
# 8.7
# /title/tt4063800/?ref_=chttvtp_t_176
# 177. A Maldição da Residência Hill
# 62 eps
# 2018
# 8.6
# /title/tt6763664/?ref_=chttvtp_t_177
# 178. Homicídio
# 62 eps
# 1993
# 8.7
# /title/tt0106028/?ref_=chttvtp_t_178
# 179. O Que Fazemos nas Sombras
# 62 eps
# 2019
# 8.6
# /title/tt7908628/?ref_=chttvtp_t_179
# 180. Liga da Justiça
# 62 eps
# 2001
# 8.6
# /title/tt0275137/?ref_=chttvtp_t_180
# 181. Dragon Ball
# 62 eps
# 1986
# 8.6
# /title/tt0088509/?ref_=chttvtp_t_181
# 182. Os Irmãos Aventura
# 62 eps
# 2003
# 8.6
# /title/tt0417373/?ref_=chttvtp_t_182
# 183. Jujutsu Kaisen
# 62 eps
# 2020
# 8.6
# /title/tt12343534/?ref_=chttvtp_t_183
# 184. O Gambito da Rainha
# 62 eps
# 2020
# 8.5
# /title/tt10048342/?ref_=chttvtp_t_184
# 185. Homem de Família
# 62 eps
# 2019
# 8.7
# /title/tt9544034/?ref_=chttvtp_t_185
# 186. Battlestar Galactica
# 62 eps
# 2003
# 8.5
# /title/tt0314979/?ref_=chttvtp_t_186
# 187. Dragon Ball
# 62 eps
# 1995
# 8.5
# /title/tt0280249/?ref_=chttvtp_t_187
# 188. Flight of the Conchords
# 62 eps
# 2007
# 8.6
# /title/tt0863046/?ref_=chttvtp_t_188
# 189. Making a Murderer
# 62 eps
# 2015
# 8.5
# /title/tt5189670/?ref_=chttvtp_t_189
# 190. Coupling
# 62 eps
# 2000
# 8.6
# /title/tt0237123/?ref_=chttvtp_t_190
# 191. Rocket Boys
# 62 eps
# 2022
# 8.9
# /title/tt13868972/?ref_=chttvtp_t_191
# 192. Samurai Champloo
# 62 eps
# 2004
# 8.6
# /title/tt0423731/?ref_=chttvtp_t_192
# 193. Sol Negro
# 62 eps
# 2017
# 8.9
# /title/tt6108262/?ref_=chttvtp_t_193
# 194. Yes, Prime Minister
# 62 eps
# 1986
# 8.6
# /title/tt0086831/?ref_=chttvtp_t_194
# 195. Endeavour
# 62 eps
# 2012
# 8.6
# /title/tt2701582/?ref_=chttvtp_t_195
# 196. Tirando a Maior Onda
# 62 eps
# 2011
# 8.6
# /title/tt2100976/?ref_=chttvtp_t_196
# 197. The Eric Andre Show
# 62 eps
# 2012
# 8.6
# /title/tt2244495/?ref_=chttvtp_t_197
# 198. The IT Crowd
# 62 eps
# 2006
# 8.5
# /title/tt0487831/?ref_=chttvtp_t_198
# 199. Mr. Robot: Sociedade Hacker
# 62 eps
# 2015
# 8.5
# /title/tt4158110/?ref_=chttvtp_t_199
# 200. Spaced
# 62 eps
# 1999
# 8.5
# /title/tt0187664/?ref_=chttvtp_t_200
# 201. Ezel
# 62 eps
# 2009
# 8.7
# /title/tt1534360/?ref_=chttvtp_t_201
# 202. I'm Alan Partridge
# 62 eps
# 1997
# 8.6
# /title/tt0129690/?ref_=chttvtp_t_202
# 203. Em Duas Rodas com Evan McGregor
# 62 eps
# 2004
# 8.6
# /title/tt0403778/?ref_=chttvtp_t_203
# 204. Samurai Jack
# 62 eps
# 2001
# 8.5
# /title/tt0278238/?ref_=chttvtp_t_204
# 205. Mob Psycho 100
# 62 eps
# 2016
# 8.6
# /title/tt5897304/?ref_=chttvtp_t_205
# 206. Detectoristas
# 62 eps
# 2014
# 8.6
# /title/tt4082744/?ref_=chttvtp_t_206
# 207. Louie
# 62 eps
# 2010
# 8.5
# /title/tt1492966/?ref_=chttvtp_t_207
# 208. Whose Line Is It Anyway?
# 62 eps
# 1998
# 8.5
# /title/tt0163507/?ref_=chttvtp_t_208
# 209. Heartstopper
# 62 eps
# 2022
# 8.6
# /title/tt10638036/?ref_=chttvtp_t_209
# 210. Happy Valley
# 62 eps
# 2014
# 8.5
# /title/tt3428912/?ref_=chttvtp_t_210
# 211. Spartacus
# 62 eps
# 2010
# 8.5
# /title/tt1442449/?ref_=chttvtp_t_211
# 212. Fórmula 1: Dirigir para Viver
# 62 eps
# 2019
# 8.5
# /title/tt8289930/?ref_=chttvtp_t_212
# 213. The Office
# 62 eps
# 2001
# 8.5
# /title/tt0290978/?ref_=chttvtp_t_213
# 214. Através do Buraco de Minhoca
# 62 eps
# 2010
# 8.6
# /title/tt1513168/?ref_=chttvtp_t_214
# 215. Filhos da Anarquia
# 62 eps
# 2008
# 8.6
# /title/tt1124373/?ref_=chttvtp_t_215
# 216. Neon Genesis Evangelion
# 62 eps
# 1995
# 8.5
# /title/tt0112159/?ref_=chttvtp_t_216
# 217. Twin Peaks: O Retorno
# 62 eps
# 2017
# 8.5
# /title/tt4093826/?ref_=chttvtp_t_217
# 218. Shameless
# 62 eps
# 2011
# 8.5
# /title/tt1586680/?ref_=chttvtp_t_218
# 219. Trailer Park Boys
# 62 eps
# 2001
# 8.5
# /title/tt0290988/?ref_=chttvtp_t_219
# 220. Brass Eye
# 62 eps
# 1997
# 8.6
# /title/tt0118273/?ref_=chttvtp_t_220
# 221. Skam
# 62 eps
# 2015
# 8.6
# /title/tt5288312/?ref_=chttvtp_t_221
# 222. Spartacus: Deuses da Arena
# 62 eps
# 2011
# 8.5
# /title/tt1758429/?ref_=chttvtp_t_222
# 223. North & South
# 62 eps
# 2004
# 8.6
# /title/tt0417349/?ref_=chttvtp_t_223
# 224. Apenas um Show
# 62 eps
# 2010
# 8.5
# /title/tt1710308/?ref_=chttvtp_t_224
# 225. Silicon Valley
# 62 eps
# 2014
# 8.5
# /title/tt2575988/?ref_=chttvtp_t_225
# 226. Letterkenny
# 62 eps
# 2016
# 8.6
# /title/tt4647692/?ref_=chttvtp_t_226
# 227. Doctor Who
# 62 eps
# 2005
# 8.6
# /title/tt0436992/?ref_=chttvtp_t_227
# 228. Schitt's Creek
# 62 eps
# 2015
# 8.5
# /title/tt3526078/?ref_=chttvtp_t_228
# 229. Futurama
# 62 eps
# 1999
# 8.5
# /title/tt0149460/?ref_=chttvtp_t_229
# 230. Fullmetal Alchemist
# 62 eps
# 2003
# 8.5
# /title/tt0421357/?ref_=chttvtp_t_230
# 231. Uma Advogada Extraordinária
# 62 eps
# 2022
# 8.6
# /title/tt20869502/?ref_=chttvtp_t_231
# 232. Derry Girls
# 62 eps
# 2018
# 8.5
# /title/tt7120662/?ref_=chttvtp_t_232
# 233. Da Terra à Lua
# 62 eps
# 1998
# 8.6
# /title/tt0120570/?ref_=chttvtp_t_233
# 234. The Expanse
# 62 eps
# 2015
# 8.5
# /title/tt3230854/?ref_=chttvtp_t_234
# 235. Rurouni Kenshin: Meiji Kenkaku Romantan: Tsuioku Hen
# 62 eps
# 1999
# 8.6
# /title/tt0203082/?ref_=chttvtp_t_235
# 236. O Ensaio
# 62 eps
# 2022
# 8.5
# /title/tt10802170/?ref_=chttvtp_t_236
# 237. Hannibal
# 62 eps
# 2013
# 8.5
# /title/tt2243973/?ref_=chttvtp_t_237
# 238. Wentworth - Por Trás das Grades
# 62 eps
# 2013
# 8.6
# /title/tt2433738/?ref_=chttvtp_t_238
# 239. Westworld
# 62 eps
# 2016
# 8.5
# /title/tt0475784/?ref_=chttvtp_t_239
# 240. A Amiga Genial
# 62 eps
# 2018
# 8.6
# /title/tt7278862/?ref_=chttvtp_t_240
# 241. Vivendo nas Sombras
# 62 eps
# 2014
# 8.7
# /title/tt4269716/?ref_=chttvtp_t_241
# 242. Avrupa Yakasi
# 62 eps
# 2004
# 8.6
# /title/tt0421291/?ref_=chttvtp_t_242
# 243. Community
# 62 eps
# 2009
# 8.5
# /title/tt1439629/?ref_=chttvtp_t_243
# 244. Alquimia das Almas
# 62 eps
# 2022
# 8.8
# /title/tt20859920/?ref_=chttvtp_t_244
# 245. Entrelinhas pontilhadas
# 62 eps
# 2021
# 8.6
# /title/tt15614372/?ref_=chttvtp_t_245
# 246. Gintama
# 62 eps
# 2005
# 8.7
# /title/tt0988818/?ref_=chttvtp_t_246
# 247. Shigatsu wa kimi no uso
# 62 eps
# 2014
# 8.5
# /title/tt3895150/?ref_=chttvtp_t_247
# 248. Chef's Table
# 62 eps
# 2015
# 8.5
# /title/tt4295140/?ref_=chttvtp_t_248
# 249. Foyle's War
# 62 eps
# 2002
# 8.6
# /title/tt0310455/?ref_=chttvtp_t_249
# 250. Sapne Vs Everyone
# 62 eps
# 2023
# 9.4
# /title/tt30263074/?ref_=chttvtp_t_250
