# %%
import requests

# %%
api_url = "https://trabalhoapirest.onrender.com/itens"
response = requests.get(api_url)

# %%
response.json()
# Out:
# [{'cast': 'Chris Diamantopoulos, Tony Anselmo, Tress MacNeille, Bill Farmer, Russi Taylor, Corey Burton',
#   'country': '',
#   'date_added': 'November 26, 2021',
#   'description': 'Join Mickey and the gang as they duck the halls!',
#   'director': 'Alonso Ramirez Ramos, Dave Wasson',
#   'duration': '23 min',
#   'listed_in': 'Animation, Family',
#   'rating': 'TV-G',
#   'release_year': 2016,
#   'show_id': 1,
#   'title': 'Duck the Halls: A Mickey Mouse Christmas Special',
#   'type': 'Movie'},
#  {'cast': 'Jim Varney, Noelle Parker, Douglas Seale',
#   'country': '',
#   'date_added': 'November 26, 2021',
#   'description': 'Santa Claus passes his magic bag to a new St. Nic.',
#   'director': 'John Cherry',
#   'duration': '91 min',
#   'listed_in': 'Comedy',
#   'rating': 'PG',
#   'release_year': 1988,
#   'show_id': 2,
#   'title': 'Ernest Saves Christmas',
#   'type': 'Movie'},
#  {'cast': 'Raymond Albert Romano, John Leguizamo, Denis Leary, Queen Latifah',
# ...

# %%
api_url = "https://trabalhoapirest.onrender.com/itens/1451"
response = requests.get(api_url)

# %%
response.json()
# Out:
# {'cast': 'Emma Stone',
#  'country': 'United States',
#  'date_added': 'April 3, 2024',
#  'description': 'Movie.',
#  'director': 'Tim Burton',
#  'duration': '120 min',
#  'listed_in': 'Drama, Action',
#  'rating': 'PG',
#  'release_year': 2024,
#  'show_id': 1451,
#  'title': 'New Movie',
#  'type': 'Movie'}

# %%
tarefa = {
    "type": "Movie",
    "title": "New Movie",
    "director": "Tim Burton",
    "cast": "Emma Stone",
    "country": "United States",
    "date_added": "April 3, 2024",
    "release_year": 2024,
    "rating": "PG",
    "duration": "120 min",
    "listed_in": "Drama, Action",
    "description": "Movie."}
api_url = "https://trabalhoapirest.onrender.com/itens"
response = requests.post(api_url, json=tarefa)

# %%
response.json()
# Out:
# {'cast': 'Emma Stone',
#  'country': 'United States',
#  'date_added': 'April 3, 2024',
#  'description': 'Movie.',
#  'director': 'Tim Burton',
#  'duration': '120 min',
#  'listed_in': 'Drama, Action',
#  'rating': 'PG',
#  'release_year': 2024,
#  'show_id': 1451,
#  'title': 'New Movie',
#  'type': 'Movie'}

# %%
api_url = "https://trabalhoapirest.onrender.com/itens/1451"
tarefa = {"director": "Matheus Krebs"}
response = requests.put(api_url, json=tarefa)
response.json()
# Out:
# {'cast': 'Emma Stone',
#  'country': 'United States',
#  'date_added': 'April 3, 2024',
#  'description': 'Movie.',
#  'director': 'Matheus Krebs',
#  'duration': '120 min',
#  'listed_in': 'Drama, Action',
#  'rating': 'PG',
#  'release_year': 2024,
#  'show_id': 1451,
#  'title': 'New Movie',
#  'type': 'Movie'}

# %%
api_url = "https://trabalhoapirest.onrender.com/itens/1450"
response = requests.delete(api_url)
response.json()
# Out:
# {'message': 'Item deletado'}
